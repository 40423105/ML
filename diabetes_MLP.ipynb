# %% [markdown]
# <a href="https://colab.research.google.com/github/40423105/ML/blob/main/diabetes_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('diabetes.csv')
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
from sklearn.model_selection import train_test_split
dataset = df.values
x = dataset[:,0:8]
y = dataset[:,8]

# %%
x -= x.mean(axis = 0)
x /= x.std(axis = 0)
x
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.3,random_state =1)

# %%
from keras.engine.input_layer import Input
model = Sequential()
model.add(Dense(10, input_shape=(8,), activation="relu")) 
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy", optimizer = 'adam',metrics = ["accuracy"])

# %%
model.fit(x_train, y_train, epochs = 150, batch_size =10)
# Out:
# Epoch 1/150
# 54/54 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.6331
# Epoch 2/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6414 - accuracy: 0.6574
# Epoch 3/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6082 - accuracy: 0.6611
# Epoch 4/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.6760
# Epoch 5/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5637 - accuracy: 0.6816
# Epoch 6/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5491 - accuracy: 0.6946
# Epoch 7/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5363 - accuracy: 0.6946
# Epoch 8/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7095
# Epoch 9/150
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5152 - accuracy: 0.7188
# Epoch 10/150
# ...

# %%
loss, accuracy = model.evaluate(x_train, y_train)
print("訓練資料集的準確度 = {:.2f}".format(accuracy))

loss, accuracy = model.evaluate(x_test, y_test)
print("測試資料集的準確度 = {:.2f}".format(accuracy))
# Out:
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8268
# 訓練資料集的準確度 = 0.83
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.7706
# 測試資料集的準確度 = 0.77

# %%
y_pred = model.predict(x_test, batch_size =10, verbose = 0)
print(y_pred[0],y_pred[1])
# Out:
# [0.54865444] [0.32683843]
